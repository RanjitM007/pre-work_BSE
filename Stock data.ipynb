# %%
import requests
import pandas as pd

# %%
import pandas as pd
import numpy as np
import requests
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
dr=webdriver.Chrome(r"C:\Users\Ranjit\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_14080\3260035234.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   dr=webdriver.Chrome(r"C:\Users\Ranjit\Downloads\chromedriver_win32\chromedriver.exe")

# %%
sourcefile='https://raw.githubusercontent.com/RanjitM007/pre-work_BSE/main/Equity.csv'
df=pd.read_csv(sourcefile)

# %%
df.head()
# Out:
#    Security Code Type                          Issuer Name Security Id  \
# 0         500002  BSE                    ABB India Limited         ABB
# 1         500003  BSE                 Aegis Logistics Ltd.    AEGISLOG
# 2         500008  BSE             Amara Raja Batteries Ltd  AMARAJABAT
# 3         500009  BSE    Ambalal Sarabhai Enterprise Ltd.,   AMBALALSA
# 4         500010  BSE  Housing Development Finance Corp.Lt        HDFC
#
#                            Security Name  Status Group  Face Value  \
# 0                      ABB India Limited  Active    A          2.0
# 1                   AEGIS LOGISTICS LTD.  Active    A          1.0
# 2              AMARA RAJA BATTERIES LTD.  Active    A          1.0
# 3      AMBALAL SARABHAI ENTERPRISES LTD.  Active    X         10.0
# 4  HOUSING DEVELOPMENT FINANCE CORP.LTD.  Active    A          2.0
#
#         ISIN No                    Industry Instrument  \
# 0  INE117A01022  Heavy Electrical Equipment     Equity
# ...

# %%
Security_Id=df['Security Id'].to_list()

# %%
def bse_history():
    j=1
    for i in Security_Id[2961:]:
        url='https://query1.finance.yahoo.com/v7/finance/download/'+i+'.BO?period1=1015891200&period2=1663718400&interval=1d&events=history&includeAdjustedClose=true'
        dr.get(url)
        time.sleep(1)
        j=j=1
        print('Records fetch for :::✔',i)

# %%
bse_history()
# Out:
# Records fetch for :::✔ SUCHITRA
# Records fetch for :::✔ DHABRIYA
# Records fetch for :::✔ ARYACAPM
# Records fetch for :::✔ PDSL
# Records fetch for :::✔ HANMAN
# Records fetch for :::✔ VGCL
# Records fetch for :::✔ STARLIT
# Records fetch for :::✔ CEINSYSTECH
# Records fetch for :::✔ PANACHE
# Records fetch for :::✔ JSHL
# Records fetch for :::✔ CRANEINFRA
# Records fetch for :::✔ NIYOGIN
# Records fetch for :::✔ ASIACAP
# Records fetch for :::✔ AKASHDEEP
# Records fetch for :::✔ CIL
# Records fetch for :::✔ GBFL
# Records fetch for :::✔ GILADAFINS
# Records fetch for :::✔ JETINFRA
# Records fetch for :::✔ SAPPL
# Records fetch for :::✔ AANCHALISP
# Records fetch for :::✔ CAPPIPES
# Records fetch for :::✔ ANUBHAV
# Records fetch for :::✔ MEL
# Records fetch for :::✔ INTELLECT
# Records fetch for :::✔ MONTECARLO
# Records fetch for :::✔ JSTL
# Records fetch for :::✔ ICL
# Records fetch for :::✔ SCC
# Records fetch for :::✔ PANAFIC
# Records fetch for :::✔ MYMONEY
# ...

# %%
for i in range(len(Security_Id)):
    if Security_Id[i] =='ATISHAY':
        print(i)
# Out:
# 2960

# %%
Security_Id[2960:9]
# Out:
# []

# %%
type(Security_Id)
# Out:
# list

# %%
len(Security_Id[2960])
# Out:
# 7
